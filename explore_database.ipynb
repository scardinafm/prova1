# %%
import sqlite3 
import pandas as pd
import create_hist_mod as ch

# %% [markdown]
# ##### Show tables in the database

# %%
database_name='raisers_edge_data.db'
conn = sqlite3.connect(database_name)
query='''SELECT name FROM sqlite_master WHERE type='table'; '''
conn.execute(query).fetchall()
# Out:
# [('Analysis_Actions_View',),
#  ('Analysis_Gift_Split_View',),
#  ('Analysis_Appeals_View',),
#  ('Analysis_Address_View',),
#  ('Analysis_Contacts_View',),
#  ('Analysis_Events_View',),
#  ('Analysis_Membership_View',),
#  ('Analysis_Primary_Numbers_View',),
#  ('Analysis_Volunteer_Types_View',)]

# %%
query="pragma table_info(Analysis_Address_View);"
schema = conn.execute(query).fetchall()
print(schema)
# Out:
# [(0, 'CONSTITUENT_ID', '', 0, None, 0), (1, 'Address_Import_ID', '', 0, None, 0), (2, 'AddressLine1', '', 0, None, 0), (3, 'AddressLine2', '', 0, None, 0), (4, 'AddressLine3', '', 0, None, 0), (5, 'AddressLine4', '', 0, None, 0), (6, 'AddressLine5', '', 0, None, 0), (7, 'City', '', 0, None, 0), (8, 'County_Name', '', 0, None, 0), (9, 'POST_CODE', '', 0, None, 0), (10, 'Country_Name', '', 0, None, 0), (11, 'Region', '', 0, None, 0), (12, 'Overseas_Address', '', 0, None, 0), (13, 'Address_Type', '', 0, None, 0), (14, 'Address_Source', '', 0, None, 0), (15, 'Preferred_Address', '', 0, None, 0), (16, 'DATE_FROM', '', 0, None, 0), (17, 'DATE_TO', '', 0, None, 0), (18, 'Date_Address_Added', '', 0, None, 0), (19, 'Date_Address_Last_Changed', '', 0, None, 0)]

# %%
# In metod creating_dataframe_from_database_querying the first argument has to be an SQL query
#and the second argument a database name
database_name='raisers_edge_data.db'
query='''select * from Analysis_Address_View ;'''
df_address_view=ch.creating_dataframe_from_database_querying(query,database_name,return_shape=True)
# Out:
# shape of created dataframe  (742707, 20)

# %%
df_address_view.head(3)
# Out:
#   CONSTITUENT_ID Address_Import_ID       AddressLine1 AddressLine2  \
# 0              0         Address_0
# 1             10        Address_10  50 Knutsford Road
# 2         100001    Address_100001               Test
#
#   AddressLine3 AddressLine4 AddressLine5           City County_Name  \
# 0
# 1                                         ALDERLEY EDGE    Cheshire
# 2
#
#     POST_CODE    Country_Name      Region Overseas_Address Address_Type  \
# 0       URN-0  United Kingdom                           No         Home
# 1     SK9 7SF  United Kingdom  North West               No         Home
# 2  URN-100001  United Kingdom                           No     Business
#
#   Address_Source Preferred_Address            DATE_FROM DATE_TO  \
# 0                              Yes
# 1                              Yes  2006-12-11 00:00:00
# 2                              Yes
#
#               Date_Address_Added      Date_Address_Last_Changed
# ...

# %%
query="pragma table_info(Analysis_Membership_View);"
schema = conn.execute(query).fetchall()
print(schema)
# Out:
# [(0, 'CONSTITUENT_ID', '', 0, None, 0), (1, 'MemID', '', 0, None, 0), (2, 'MemImportid', '', 0, None, 0), (3, 'PrimaryMember', '', 0, None, 0), (4, 'Date_Joined', '', 0, None, 0), (5, 'LastRenewedDate', '', 0, None, 0), (6, 'LastDroppedDate', '', 0, None, 0), (7, 'TimesRenewed', '', 0, None, 0), (8, 'ConsecYears', '', 0, None, 0), (9, 'TotalYears', '', 0, None, 0), (10, 'Current_Standing', '', 0, None, 0)]

# %%
# In metod creating_dataframe_from_database_querying the first argument has to be an SQL query
#and the second argument a database name
database_name='raisers_edge_data.db'
query='''select * from Analysis_Membership_View ;'''
df_membership_view=ch.creating_dataframe_from_database_querying(query,database_name,return_shape=True)
# Out:
# shape of created dataframe  (108896, 11)

# %%
df_membership_view.head(30)
# Out:
#    CONSTITUENT_ID MemID MemImportid PrimaryMember          Date_Joined  \
# 0              10                10            -1  1989-04-01 00:00:00
# 1          100011            100011            -1  1994-04-01 00:00:00
# 2          100014            100014            -1  1994-04-29 00:00:00
# 3          100035            100035            -1  1994-04-01 00:00:00
# 4          100037            100037            -1  1994-05-11 00:00:00
# 5          100038            100038            -1  1994-05-11 00:00:00
# 6          100039            100039            -1  1994-05-11 00:00:00
# 7          100040            100040            -1  1994-04-01 00:00:00
# 8          100042            100042            -1  1994-07-01 00:00:00
# 9          100049            100049            -1  1994-12-23 00:00:00
# 10         100050            100050            -1  1996-04-03 00:00:00
# 11         100054            100054            -1  2002-07-01 00:00:00
# ...

# %%
query="pragma table_info(Analysis_Gift_Split_View);"
schema = conn.execute(query).fetchall()
print(schema)
# Out:
# [(0, 'CONSTITUENT_ID', '', 0, None, 0), (1, 'GIFT_ID', '', 0, None, 0), (2, 'Gift_Import_id', '', 0, None, 0), (3, 'Gift_Date', '', 0, None, 0), (4, 'Gift_Amount', '', 0, None, 0), (5, 'Gift_Aid_Status', '', 0, None, 0), (6, 'Gift_Aid_Amount', '', 0, None, 0), (7, 'CampaignId', '', 0, None, 0), (8, 'Campaign', '', 0, None, 0), (9, 'FundId', '', 0, None, 0), (10, 'Fund', '', 0, None, 0), (11, 'APPEAL_ID', '', 0, None, 0), (12, 'Appeal', '', 0, None, 0), (13, 'Gift_Type', '', 0, None, 0), (14, 'GiftSubType', '', 0, None, 0), (15, 'Payment_Type', '', 0, None, 0), (16, 'Acknowledged', '', 0, None, 0), (17, 'Letter', '', 0, None, 0), (18, 'Date_Gift_Added', '', 0, None, 0), (19, 'Date_Gift_Changed', '', 0, None, 0), (20, 'Gift_Split_ID', '', 0, None, 0)]

# %%
# In metod creating_dataframe_from_database_querying the first argument has to be an SQL query
#and the second argument a database name
database_name='raisers_edge_data.db'
query='''select * from  Analysis_Gift_Split_View ;'''
df_gift_view=ch.creating_dataframe_from_database_querying(query,database_name,return_shape=True)
# Out:
# shape of created dataframe  (3646303, 21)

# %%
df_gift_view.head(3)
# Out:
#   CONSTITUENT_ID GIFT_ID Gift_Import_id            Gift_Date Gift_Amount  \
# 0             10      22         Gift_6  1984-09-25 00:00:00         4.0
# 1             10      23      Gift_7057  1987-12-10 00:00:00         3.4
# 2             10      24     Gift_27537  1989-10-20 00:00:00         1.0
#
#               Gift_Aid_Status Gift_Aid_Amount CampaignId Campaign FundId  \
# 0  Not Qualified For Gift Aid             0.0                        350
# 1  Not Qualified For Gift Aid             0.0                        350
# 2  Not Qualified For Gift Aid             0.0                        350
#
#        ...      APPEAL_ID                             Appeal Gift_Type  \
# 0      ...         R-R011                  General Donations      Cash
# 1      ...         R-R011                  General Donations      Cash
# 2      ...         R-BRAN  Branch payment to National Office      Cash
#
#            GiftSubType Payment_Type      Acknowledged Letter  \
# ...

# %%
query="pragma table_info(Analysis_Volunteer_Types_View);"
schema = conn.execute(query).fetchall()
print(schema)
# Out:
# [(0, 'CONSTITUENT_ID', '', 0, None, 0), (1, 'Volunteer_Type_Code', '', 0, None, 0), (2, 'Volunteer_Type_Desc', '', 0, None, 0), (3, 'DATE_STARTED', '', 0, None, 0), (4, 'DATE_FINISHED', '', 0, None, 0), (5, 'Status_Code', '', 0, None, 0), (6, 'Status_Desc', '', 0, None, 0)]

# %%
# In metod creating_dataframe_from_database_querying the first argument has to be an SQL query
#and the second argument a database name
database_name='raisers_edge_data.db'
query='''select * from Analysis_Volunteer_Types_View ;'''
df_volunteer_view=ch.creating_dataframe_from_database_querying(query,database_name,return_shape=True)
# Out:
# shape of created dataframe  (7072, 7)

# %%
df_volunteer_view.head(3)
# Out:
#   CONSTITUENT_ID Volunteer_Type_Code         Volunteer_Type_Desc DATE_STARTED  \
# 0         101622              4811.0  Branch Committee Volunteer   20120320.0
# 1         101662              4811.0  Branch Committee Volunteer   19950101.0
# 2         104585              4811.0  Branch Committee Volunteer   20060307.0
#
#   DATE_FINISHED Status_Code Status_Desc
# 0                    4730.0      Active
# 1                    4730.0      Active
# 2                    4730.0      Active

# %%
query="pragma table_info(Analysis_Events_View);"
schema = conn.execute(query).fetchall()
print(schema)
# Out:
# [(0, 'CONSTITUENT_ID', '', 0, None, 0), (1, 'EVENTID', '', 0, None, 0), (2, 'NAME', '', 0, None, 0), (3, 'Participant_Registration', '', 0, None, 0), (4, 'Participation_Type', '', 0, None, 0), (5, 'Participant_Has_Attended', '', 0, None, 0), (6, 'Participant_Type', '', 0, None, 0), (7, 'EventStartDate', '', 0, None, 0), (8, 'Event_Type', '', 0, None, 0)]

# %%
# In metod creating_dataframe_from_database_querying the first argument has to be an SQL query
#and the second argument a database name
database_name='raisers_edge_data.db'
query='''select * from Analysis_Events_View ;'''
df_events_view=ch.creating_dataframe_from_database_querying(query,database_name,return_shape=True)
# Out:
# shape of created dataframe  (174392, 9)

# %%
df_events_view.head(3)
# Out:
#   CONSTITUENT_ID EVENTID                                     NAME  \
# 0         114328     944  Mid Value Wales and WM Stewardship 2015
# 1         114402    1164         Ian Fowler Memorial Lecture 2016
# 2         114674     100                 Mervyn Peake Awards 2007
#
#   Participant_Registration Participation_Type Participant_Has_Attended  \
# 0           Not registered                                          No
# 1           Not registered                                          No
# 2           Not registered                                          No
#
#   Participant_Type       EventStartDate             Event_Type
# 0       Registrant  2015-06-24 00:00:00            Cultivation
# 1       Registrant  2016-05-26 00:00:00  In aid of fundraising
# 2       Registrant  2007-01-01 00:00:00       User involvement

# %%
query="pragma table_info(Analysis_Appeals_View);"
schema = conn.execute(query).fetchall()
print(schema)
# Out:
# [(0, 'CONSTITUENT_ID', '', 0, None, 0), (1, 'Appeal_Date', '', 0, None, 0), (2, 'appeal_id', '', 0, None, 0), (3, 'Appeal', '', 0, None, 0), (4, 'Package_id', '', 0, None, 0), (5, 'Package', '', 0, None, 0), (6, 'Package_Attribue', '', 0, None, 0), (7, 'Value', '', 0, None, 0), (8, 'Constituent_Appeal_Import_ID', '', 0, None, 0), (9, 'Constituent_Appeal_ID', '', 0, None, 0)]

# %%
# In metod creating_dataframe_from_database_querying the first argument has to be an SQL query
#and the second argument a database name
database_name='raisers_edge_data.db'
query='''select * from Analysis_Appeals_View ;'''
df_appeals_view=ch.creating_dataframe_from_database_querying(query,database_name,return_shape=True)
# Out:
# shape of created dataframe  (4582216, 10)

# %%
df_appeals_view.head(3)
# Out:
#   CONSTITUENT_ID          Appeal_Date         appeal_id  \
# 0         184099  2004-03-31 00:00:00  R-R022-0403-PD01
# 1         184118  2004-03-31 00:00:00  R-R022-0403-PD01
# 2         184119  2004-03-31 00:00:00  R-R022-0403-PD01
#
#                         Appeal Package_id                      Package  \
# 0  Prize Draw 2004 and earlier         86  04 Raffle - Lapsed (Donors)
# 1  Prize Draw 2004 and earlier         86  04 Raffle - Lapsed (Donors)
# 2  Prize Draw 2004 and earlier         86  04 Raffle - Lapsed (Donors)
#
#   Package_Attribue Value Constituent_Appeal_Import_ID Constituent_Appeal_ID
# 0                                01571-036-0000210154                210154
# 1                                01571-036-0000210158                210158
# 2                                01571-036-0000210159                210159

# %%
# In metod creating_dataframe_from_database_querying the first argument has to be an SQL query
#and the second argument a database name
database_name='raisers_edge_data.db'
query='''select * from Analysis_Actions_View limit 1000;'''
df_actions_view=ch.creating_dataframe_from_database_querying(query,database_name,return_shape=True)
# Out:
# shape of created dataframe  (1000, 11)

# %%
df_actions_view.head(10)
# Out:
#   CONSTITUENT_ID          Action_Date Action_Category         Action_Type  \
# 0         191562  1998-04-01 00:00:00      Task/Other            Approach
# 1         191379  1998-06-30 00:00:00      Task/Other            Approach
# 2         191397  1998-07-01 00:00:00      Task/Other  Tr - Proposal Sent
# 3         191427  1998-07-01 00:00:00      Task/Other            Approach
# 4         191336  1998-09-01 00:00:00      Task/Other       Tr - Proposal
# 5         192114  1998-07-31 00:00:00      Task/Other            Approach
# 6         192227  1998-08-03 00:00:00      Task/Other            Approach
# 7         191432  1998-07-02 00:00:00      Task/Other      Tr - Thank You
# 8         190735  1998-07-03 00:00:00      Task/Other            Approach
# 9         190736  1998-07-07 00:00:00      Task/Other                 P4P
#
#                    Action_Status Action_Completed                      Letter  \
# ...

# %%
# In metod creating_dataframe_from_database_querying the first argument has to be an SQL query
#and the second argument a database name
database_name='raisers_edge_data.db'
query='''select * from Analysis_Contacts_View limit 1000;'''
df_contacts_view=ch.creating_dataframe_from_database_querying(query,database_name,return_shape=True)
# Out:
# shape of created dataframe  (1000, 14)

# %%
df_contacts_view.head(10)
# Out:
#   CONSTITUENT_ID IMPORT_ID Title First_Name                         Last_Name  \
# 0              0         0                   Anon IM Deceased 2000 Conversion
# 1             10        10   Mrs        Ivy                            Dutton
# 2         100001    100001
# 3         100004    100004                                             Mather
# 4         100005    100005                                            Langham
# 5         100008    100008                                          Hutchings
# 6         100011    100011   Mrs      Doris                              Lobl
# 7         100013    100013                                           Bradford
# 8         100014    100014   Mrs          A                             Jones
# 9         100017    100017                                            Chapman
#
#   Company_Name Primary_Salutation DOB   Gender Deceased Deceased_Date  \
# 0                                      Unknown       No
# ...

# %%
# In metod creating_dataframe_from_database_querying the first argument has to be an SQL query
#and the second argument a database name
database_name='raisers_edge_data.db'
query='''select * from Analysis_Contacts_View ;'''
df_primary_number_view=ch.creating_dataframe_from_database_querying(query,database_name,return_shape=True)
# Out:
# shape of created dataframe  (742704, 14)

# %%
df_primary_number_view.head(20)
# Out:
#    CONSTITUENT_ID IMPORT_ID Title First_Name  \
# 0               0         0
# 1              10        10   Mrs        Ivy
# 2          100001    100001
# 3          100004    100004
# 4          100005    100005
# 5          100008    100008
# 6          100011    100011   Mrs      Doris
# 7          100013    100013
# 8          100014    100014   Mrs          A
# 9          100017    100017
# 10         100023    100023
# 11         100024    100024
# 12         100026    100026
# 13         100027    100027   Mrs      Doris
# 14         100029    100029
# 15         100033    100033    Mr          W
# 16         100034    100034
# 17         100035    100035    Mr       Paul
# 18         100037    100037   Mrs   Margaret
# 19         100038    100038    Mr      Mario
#
#                            Last_Name Company_Name Primary_Salutation  \
# 0   Anon IM Deceased 2000 Conversion
# 1                             Dutton
# 2                                        Pettifer
# ...

# %%
twitter_null = pd.isnull(df_primary_number_view["Twitter"])
df_primary_number_view_new=df_primary_number_view[twitter_null ==False]

# %%
df_primary_number_view.shape
# Out:
# (8653513, 11)

# %%
a=df_primary_number_view_new['Twitter'].iloc[1]
print(a,type(a),len(a))
# Out:
#  <class 'str'> 0

# %%
for i in df_primary_number_view["Supporter_Type"].iloc[0:1000]:
    if len(i) >0:
        print(i)
# Out:
# I
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# O
# I
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# O
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# O
# I
# I
# I
# I
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# O
# I
# I
# I
# I
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# O
# I
# I
# I
# I
# I
# I
# I
# I
# I
# ...

# %%
import pickle
documents_f = open("Mosaic_dataframe.pickle", "rb") ####
df_mosaic = pickle.load(documents_f)
documents_f.close()

# %%
a=list_columns=list(df_mosaic.columns.values)
print(a)
# Out:
# ['TC_Customer Number', 'TC_Name1', 'TC_Name', 'TC_Address1', 'TC_Address2', 'TC_Address3', 'TC_Post Town', 'TC_County', 'TC_Postcode', 'TC_Postal Sector', 'TC_Original Source_Description', 'TC_Original Source Grouping', 'TC_Source_Code', 'TC_Source Grouping', 'TC_Date Added', 'TC_Email', 'TC_Status Flag_Deceased', 'TC_Status Flag_Goneaway', 'TC_Status Flag_No Mail', 'TC_Third Party Status Flag', 'TC_Email Flag', 'TC_Salutation', 'TC_Job Title', 'TC_Telephone', 'TC_Alt Account Number', 'TC_Most Recent RE Constituent ID', 'TO_Order Number', 'TO_Media_Code', 'TO_Media_Description', 'TO_Media Grouping', 'TO_Order Date', 'TO_Order Source', 'TO_Postage', 'TOD_Product_Code', 'TOD_Product_Description', 'TOD_Product Sub Category', 'TOD_Product Category', 'TOD_Quantity', 'TOD_Net Value', 'TOD_VAT']

# %%
df_CDL=pd.read_excel("CDL_data.xlsx")
df_CDL.head(2)
# Out:
#   OrderNumber  OrderDate SalesChannel    Item             ItemName  \
# 0  SO00000014 2012-12-03    Telephone  PKB065  Parkinsons And Diet
# 1  SO00000014 2012-12-03    Telephone  PKB071        Carer's Guide
#
#    QTYORDERED ContactPersonName DELIVERYNAME DeliveryAddressLine1  \
# 0           1        Mrs Davies   Mrs Davies                    6
# 1           1        Mrs Davies   Mrs Davies                    6
#
#   DeliveryAddressLine2     ...     DELIVERYCITY DELIVERYCOUNTY DELIVERYSTATE  \
# 0        Tulip Gardens     ...           Havant      Hampshire     Hampshire
# 1        Tulip Gardens     ...           Havant      Hampshire     Hampshire
#
#   DeliveryPostcode DeliveryCountry Email         PHONE Unnamed: 19  \
# 0          PO9 3BQ  United Kingdom   NaN  02392 450307         NaN
# 1          PO9 3BQ  United Kingdom   NaN  02392 450307         NaN
#
#   Unnamed: 20 Unnamed: 21
# 0         NaN         NaN
# 1         NaN         NaN
#
# [2 rows x 22 columns]

# %%
for i in df_CDL["TO_Order Source"].iloc[0:1000]:
    #if len(i) >0:
        print(i)
# Out:
# Mail
# Mail
# Mail
# Phone
# Phone
# Phone
# Phone
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Phone
# Web
# Web
# Mail
# Mail
# Web
# Web
# Web
# Web
# Web
# Web
# Phone
# Phone
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Phone
# Web
# Web
# Web
# Phone
# Phone
# Phone
# Mail
# Web
# Web
# Mail
# Mail
# Mail
# Mail
# Mail
# Phone
# Phone
# Phone
# Phone
# Phone
# Phone
# Phone
# Phone
# Web
# Web
# Web
# Mail
# Mail
# Web
# Web
# Phone
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Phone
# Phone
# Phone
# Phone
# Phone
# Phone
# Phone
# Web
# Web
# Web
# Web
# Web
# Web
# Web
# Mail
# Mail
# Mail
# Mail
# Phone
# Phone
# Phone
# Phone
# Phone
# Web
# Web
# Web
# Web
# Mail
# Mail
# Mail
# Mail
# Mail
# Web
# Web
# Web
# Web
# Phone
# Phone
# Phone
# Email
# Email
# Email
# Email
# Email
# Email
# Email
# Email
# Email
# Email
# Email
# ...
